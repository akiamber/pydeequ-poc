# %%
import findspark

# %%
findspark.init('/home/ec2-user/spark-2.4.7-bin-hadoop2.7')

# %%
from pyspark.sql import SparkSession, Row, DataFrame
import pydeequ

# %%
##wrapper function for pydeequ

import pyspark.sql.functions as F
from pydeequ.pandas_utils import ensure_pyspark_df
import mysql.connector
from mysql.connector import Error
#from pydeequ.verification import VerificationResult


class MetricsRepository(pydeequ.repository.MetricsRepository):
    
    @classmethod
    def helper_metrics_file(cls, spark_session: SparkSession, filename: str = "metrics.json", path: str = None):
        """
        Helper method to create the metrics file for storage
        """
        if path is None:
            path = spark_session._jvm.com.google.common.io.Files.createTempDir()          
        f = spark_session._jvm.java.io.File(path, filename)
        f_path = f.getAbsolutePath()
        return f_path
    
    @classmethod
    def create_db_connection(cls):
        conn = None
        try:
            conn = mysql.connector.connect(host='host.us-east-1.rds.amazonaws.com',
                                           port='3306',
                                           database='pydeequ_metrics',
                                           user='<dbuser>',
                                           password='<dbpassword>')
            if conn.is_connected():
                return conn
        except Error as e:
            print(e)
            return None
        
    @classmethod
    def close_db_connection(cls, con):
        if con is not None and con.is_connected():
            con.close()
            

class FileSystemMetricsRepository(pydeequ.repository.FileSystemMetricsRepository,MetricsRepository):
    
    def __init__(self, spark_session: SparkSession, path: str = None):

        self._spark_session = spark_session
        self._jvm = spark_session._jvm
        self._jspark_session = spark_session._jsparkSession
        if not path: path = self.helper_metrics_file(self._spark_session)
        self.path = path
        self.deequFSmetRep = spark_session._jvm.com.amazon.deequ.repository.fs.FileSystemMetricsRepository
        self.repository = self.deequFSmetRep(self._jspark_session, path)
        super().__init__(spark_session, path)

class DatabaseMetricsRepository(MetricsRepository):
    
    def __init__(self, con):
        self.con = con
        #TODO create connection and store it it self_con
        cursor = self.con.cursor()
        self.metric_table =cursor.execute("CREATE TABLE IF NOT EXISTS " \
                                          "`metrics`(`entity` varchar(255), `instance` varchar(255), " \
                                          "`name` varchar(255), `value` float, `tag` varchar(255), " \
                                          "`timestamp` varchar(255) ) ")

        

class AnalysisRunner:
    """
    Runs a set of analyzers on the data at hand and optimizes the resulting computations to minimize
    the number of scans over the data. Additionally, the internal states of the computation can be
    stored and aggregated with existing states to enable incremental computations.
    :param spark_session SparkSession: SparkSession
    """

    def __init__(self, spark_session: SparkSession):
        self._spark_session = spark_session

    def onData(self, df):
        """
        Starting point to construct an AnalysisRun.
        :param dataFrame df: tabular data on which the checks should be verified
        :return: new AnalysisRunBuilder object
        """
        df = ensure_pyspark_df(self._spark_session, df)
        return AnalysisRunBuilder(self._spark_session, df)
    
class AnalyzerContext(pydeequ.analyzers.AnalyzerContext):
    
    @classmethod
    def addUpdateRepository(self,spark_session: SparkSession, tag_value: str ='my new column',df_metrics: DataFrame= None):
               
        df_metrics = df_metrics.withColumn('tag',F.lit(tag_value)) \
                               .withColumn('timestamp',F.current_timestamp().cast(StringType()))
        df_metrics.write.format('jdbc').options(
        url='jdbc:mysql://host.us-east-1.rds.amazonaws.com:3306/pydeequ_metrics',
        driver='com.mysql.jdbc.Driver',
        dbtable='metrics',
        user='<dbuser>',
        password='<dbpassword>').mode('append').save()
        return self

class AnalysisRunBuilder(pydeequ.analyzers.AnalysisRunBuilder):
    
    def __init__(self, spark_session: SparkSession, df: DataFrame ):
        self._spark_session = spark_session
        self._jvm = spark_session._jvm
        self._jspark_session = spark_session._jsparkSession
        self._df = df
        self._AnalysisRunBuilder = self._jvm.com.amazon.deequ.analyzers.runners.AnalysisRunBuilder(df._jdf)
        super().__init__(spark_session, df)
        
    
class VerificationResult(pydeequ.verification.VerificationResult):
    
    @classmethod
    def addUpdateRepository(self,spark_session: SparkSession, tag_value: str ='my new column',df_metrics: DataFrame= None):
               
        df_metrics = df_metrics.withColumn('tag',F.lit(tag_value)) \
                               .withColumn('timestamp',F.current_timestamp().cast(StringType()))
        df_metrics.write.format('jdbc').options(
        url='jdbc:mysql://host.us-east-1.rds.amazonaws.com:3306/pydeequ_metrics',
        driver='com.mysql.jdbc.Driver',
        dbtable='metrics',
        user='<dbuser>',
        password='<dbpassword>').mode('append').save()
        return df_metrics

# %%
##create spark session
spark = (SparkSession
    .builder
    .config("spark.jars.packages", pydeequ.deequ_maven_coord)
    .config("spark.jars.excludes", pydeequ.f2j_maven_coord)
    .getOrCreate())

# %%
#load data
df = spark.read.csv('/home/ec2-user/spark-2.4.7-bin-hadoop2.7/examples/src/main/resources/1000 Records.csv',header=True)

# %%
df.printSchema()
df.show(1)
# Out:
# root
#  |-- Emp ID: string (nullable = true)
#  |-- Name Prefix: string (nullable = true)
#  |-- First Name: string (nullable = true)
#  |-- Middle Initial: string (nullable = true)
#  |-- Last Name: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- E Mail: string (nullable = true)
#  |-- Father's Name: string (nullable = true)
#  |-- Mother's Name: string (nullable = true)
#  |-- Mother's Maiden Name: string (nullable = true)
#  |-- Date of Birth: string (nullable = true)
#  |-- Time of Birth: string (nullable = true)
#  |-- Age in Yrs.: string (nullable = true)
#  |-- Weight in Kgs.: string (nullable = true)
#  |-- Date of Joining: string (nullable = true)
#  |-- Quarter of Joining: string (nullable = true)
#  |-- Half of Joining: string (nullable = true)
#  |-- Year of Joining: string (nullable = true)
#  |-- Month of Joining: string (nullable = true)
#  |-- Month Name of Joining: string (nullable = true)
#  |-- Short Month: string (nullable = true)
#  |-- Day of Joining: string (nullable = true)
#  |-- DOW of Joining: string (nullable = true)
#  |-- Short DOW: string (nullable = true)
#  |-- Age in Company (Years): string (nullable = true)
#  |-- Salary: string (nullable = true)
#  |-- Last % Hike: string (nullable = true)
#  |-- SSN: string (nullable = true)
#  |-- Phone No. : string (nullable = true)
#  |-- Place Name: string (nullable = true)
#  |-- County: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Zip: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- User Name: string (nullable = true)
#  |-- Password: string (nullable = true)
#
# +------+-----------+----------+--------------+---------+------+--------------------+-------------+-------------+--------------------+-------------+-------------+-----------+--------------+---------------+------------------+---------------+---------------+----------------+---------------------+-----------+--------------+--------------+---------+----------------------+------+-----------+-----------+------------+----------+------+---------+-----+-----+------+---------+---------------+
# |Emp ID|Name Prefix|First Name|Middle Initial|Last Name|Gender|              E Mail|Father's Name|Mother's Name|Mother's Maiden Name|Date of Birth|Time of Birth|Age in Yrs.|Weight in Kgs.|Date of Joining|Quarter of Joining|Half of Joining|Year of Joining|Month of Joining|Month Name of Joining|Short Month|Day of Joining|DOW of Joining|Short DOW|Age in Company (Years)|Salary|Last % Hike|        SSN|  Phone No. |Place Name|County|     City|State|  Zip|Region|User Name|       Password|
# +------+-----------+----------+--------------+---------+------+--------------------+-------------+-------------+--------------------+-------------+-------------+-----------+--------------+---------------+------------------+---------------+---------------+----------------+---------------------+-----------+--------------+--------------+---------+----------------------+------+-----------+-----------+------------+----------+------+---------+-----+-----+------+---------+---------------+
# |850297|        Ms.|    Shawna|             W|     Buck|     F|shawna.buck@gmail...| Rosario Buck|  Keisha Buck|           Hendricks|   12/12/1971|  06:34:47 AM|      45.66|            44|     12/18/2010|                Q4|             H2|           2010|              12|             December|        Dec|            18|      Saturday|      Sat|                  6.61|119090|        17%|222-11-7603|702-771-7149| Las Vegas| Clark|Las Vegas|   NV|89128|  West|   swbuck|ja8?k3BTF^]o@<&|
# +------+-----------+----------+--------------+---------+------+--------------------+-------------+-------------+--------------------+-------------+-------------+-----------+--------------+---------------+------------------+---------------+---------------+----------------+---------------------+-----------+--------------+--------------+---------+----------------------+------+-----------+-----------+------------+----------+------+---------+-----+-----+------+---------+---------------+
# only showing top 1 row

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import (StructField, IntegerType,DoubleType,
                               StringType,StructType)

df =df.withColumn("Salary",col("Salary").cast(DoubleType()))
df =df.withColumn("Date of Joining",col("Date of Joining").cast(IntegerType()))
df =df.withColumn('Age in Company (Years)',col('Age in Company (Years)').cast(IntegerType()))
df=df.withColumnRenamed('Weight in Kgs.','Weight in Kgs') \
     .withColumnRenamed('Age in Yrs.','Age in Yrs') \
     .withColumnRenamed('Phone No. ','Phone No')
df=df.withColumn('Weight in Kgs',col('Weight in Kgs').cast(DoubleType())) \
     .withColumn('Age in Yrs',col('Age in Yrs').cast(DoubleType())) \
     .withColumn('Month of Joining',col('Month of Joining').cast(IntegerType())) \
     .withColumn('Phone No',col('Phone No').cast(IntegerType()))

# %%
df.printSchema()
# Out:
# root
#  |-- Emp ID: string (nullable = true)
#  |-- Name Prefix: string (nullable = true)
#  |-- First Name: string (nullable = true)
#  |-- Middle Initial: string (nullable = true)
#  |-- Last Name: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- E Mail: string (nullable = true)
#  |-- Father's Name: string (nullable = true)
#  |-- Mother's Name: string (nullable = true)
#  |-- Mother's Maiden Name: string (nullable = true)
#  |-- Date of Birth: string (nullable = true)
#  |-- Time of Birth: string (nullable = true)
#  |-- Age in Yrs: double (nullable = true)
#  |-- Weight in Kgs: double (nullable = true)
#  |-- Date of Joining: integer (nullable = true)
#  |-- Quarter of Joining: string (nullable = true)
#  |-- Half of Joining: string (nullable = true)
#  |-- Year of Joining: string (nullable = true)
#  |-- Month of Joining: integer (nullable = true)
#  |-- Month Name of Joining: string (nullable = true)
#  |-- Short Month: string (nullable = true)
#  |-- Day of Joining: string (nullable = true)
#  |-- DOW of Joining: string (nullable = true)
#  |-- Short DOW: string (nullable = true)
#  |-- Age in Company (Years): integer (nullable = true)
#  |-- Salary: double (nullable = true)
#  |-- Last % Hike: string (nullable = true)
#  |-- SSN: string (nullable = true)
#  |-- Phone No: integer (nullable = true)
#  |-- Place Name: string (nullable = true)
#  |-- County: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Zip: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- User Name: string (nullable = true)
#  |-- Password: string (nullable = true)

# %%
#store data in database
con = DatabaseMetricsRepository.create_db_connection()
db_repo = DatabaseMetricsRepository(con)

# %%
#store data in file
from pydeequ.analyzers import ResultKey

metrics_file = FileSystemMetricsRepository.helper_metrics_file(spark, 'verify_newfile.json','/home/ec2-user/')
repository = FileSystemMetricsRepository(spark, metrics_file)
key_tags = {'tag': 'analyzer'}

resultKey = ResultKey(spark, ResultKey.current_milli_time(), key_tags)

# %%
from pydeequ.analyzers import (Completeness, Compliance, ApproxCountDistinct,
                               Size,Mean, Correlation, MutualInformation, PatternMatch)
######Profiling#############
analysisResult = AnalysisRunner(spark) \
                    .onData(df) \
                    .addAnalyzer(Size()) \
                    .addAnalyzer(Completeness("Emp ID")) \
                    .addAnalyzer(ApproxCountDistinct('Emp ID')) \
                    .addAnalyzer(Mean('Salary')) \
                    .addAnalyzer(Completeness('Month of Joining')) \
                    .addAnalyzer(Compliance("Salary greater than 10000","Salary >=55000")) \
                    .addAnalyzer(Correlation('Age in Company (Years)','Age in Yrs')) \
                    .addAnalyzer(Correlation('Age in Yrs','Salary')) \
                    .addAnalyzer(Correlation('Age in Yrs','Weight in Kgs')) \
                    .addAnalyzer(MutualInformation(['Age in Yrs','Weight in Kgs'])) \
                    .addAnalyzer(MutualInformation(['Age in Yrs','Age in Company (Years)'])) \
                    .useRepository(repository) \
                    .saveOrAppendResult(resultKey) \
                    .run()

# %%
repository.path
# Out:
# '/home/ec2-user/verify_newfile.json'

# %%
##refactor analysis result as dataframe
analysisResult_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysisResult)

# %%
analysisResult_df.show(truncate=False)
# Out:
# +-----------+---------------------------------+-------------------+--------------------+
# |entity     |instance                         |name               |value               |
# +-----------+---------------------------------+-------------------+--------------------+
# |Column     |Emp ID                           |Completeness       |1.0                 |
# |Column     |Emp ID                           |ApproxCountDistinct|990.0               |
# |Column     |Month of Joining                 |Completeness       |1.0                 |
# |Mutlicolumn|Age in Yrs,Age in Company (Years)|MutualInformation  |3.129138342929379   |
# |Mutlicolumn|Age in Yrs,Weight in Kgs         |MutualInformation  |3.6304269674121072  |
# |Mutlicolumn|Age in Yrs,Salary                |Correlation        |0.041421648278586576|
# |Dataset    |*                                |Size               |1000.0              |
# |Column     |Salary                           |Mean               |120288.528          |
# |Column     |Salary greater than 10000        |Compliance         |0.932               |
# |Mutlicolumn|Age in Company (Years),Age in Yrs|Correlation        |0.675074596712711   |
# |Mutlicolumn|Age in Yrs,Weight in Kgs         |Correlation        |-0.0656561971574341 |
# +-----------+---------------------------------+-------------------+--------------------+

# %%
#add analysisresult dataframe to database
AnalyzerContext.addUpdateRepository(spark,'analyzer',analysisResult_df)
# Out:
# __main__.AnalyzerContext

# %%
#########verification and check

# %%
#get data from database table; to be passed on to verificationsuite
def getMonths_df():
    months_df =spark.read.format('jdbc').options(
        url='jdbc:mysql://host.us-east-1.rds.amazonaws.com:3306/pydeequ_metrics',
        driver='com.mysql.jdbc.Driver',
        dbtable='months',
        user='<dbuser>',
        password='<dbpassword>').load()
    print(months_df)
    return months_df
    
mylist=getMonths_df().select('months_val').rdd.map(lambda row : row[0]).collect()
mylist1=list(getMonths_df().select('months_val').toPandas()['months_val'])
print(mylist1)
# Out:
# DataFrame[months_val: string, months_val_short: string]
# DataFrame[months_val: string, months_val_short: string]
# ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
from pydeequ.verification import VerificationSuite, VerificationResult
from pydeequ.checks import *

key_tags = {'tag': 'verification_Check'}
resultKey = ResultKey(spark, ResultKey.current_milli_time(), key_tags)


_check = Check(spark, CheckLevel.Error, "Review Check") \
         .hasSize(lambda x: x>= 1000) \
         .isComplete("First Name") \
         .isComplete("Month of Joining") \
         .isContainedIn("Month of Joining",mylist) \
         .isComplete("Phone No") \
         .containsEmail("E Mail") \
         .containsSocialSecurityNumber("SSN") \
         .isUnique("Emp ID")

checkResult = VerificationSuite(spark) \
    .onData(df) \
    .addCheck(_check) \
    .useRepository(repository) \
    .saveOrAppendResult(resultKey) \
    .run()
# Out:
# Python Callback server started!

# %%
checkResult_df = VerificationResult.checkResultsAsDataFrame(spark, checkResult, pandas=True)
checkResult_df
# Out:
#           check check_level check_status  \
# 0  Review Check       Error        Error
# 1  Review Check       Error        Error
# 2  Review Check       Error        Error
# 3  Review Check       Error        Error
# 4  Review Check       Error        Error
# 5  Review Check       Error        Error
# 6  Review Check       Error        Error
# 7  Review Check       Error        Error
#
#                                           constraint constraint_status  \
# 0                         SizeConstraint(Size(None))           Success
# 1  CompletenessConstraint(Completeness(First Name...           Success
# 2  CompletenessConstraint(Completeness(Month of J...           Success
# 3  ComplianceConstraint(Compliance(Month of Joini...           Failure
# 4  CompletenessConstraint(Completeness(Phone No,N...           Failure
# 5                              containsEmail(E Mail)           Success
# 6                  containsSocialSecurityNumber(SSN)           Success
# 7  UniquenessConstraint(Uniqueness(List(Emp ID),N...           Success
#
#                                   constraint_message
# 0
# 1
# 2
# 3  Value: 0.0 does not meet the constraint requir...
# 4  Value: 0.0 does not meet the constraint requir...
# 5
# 6
# 7

# %%
checkResult_df1 = VerificationResult.successMetricsAsDataFrame(spark, checkResult)

# %%
checkResult_df1.show()
# Out:
# +-------+--------------------+------------+------+
# | entity|            instance|        name| value|
# +-------+--------------------+------------+------+
# | Column|    Month of Joining|Completeness|   1.0|
# | Column|                 SSN|PatternMatch|   1.0|
# | Column|              E Mail|PatternMatch|   1.0|
# | Column|Month of Joining ...|  Compliance|   0.0|
# |Dataset|                   *|        Size|1000.0|
# | Column|              Emp ID|  Uniqueness|   1.0|
# | Column|            Phone No|Completeness|   0.0|
# | Column|          First Name|Completeness|   1.0|
# +-------+--------------------+------------+------+

# %%
##insert verification analysis in database
VerificationResult.addUpdateRepository(spark,'verification_Check',checkResult_df1)
# Out:
# DataFrame[entity: string, instance: string, name: string, value: double, tag: string, timestamp: string]

# %%
#load the metrics file

result_metrep_df = repository.load() \
    .before(ResultKey.current_milli_time()) \
    .getSuccessMetricsAsDataFrame()
result_metrep_df.show()
# Out:
# +-----------+--------------------+-------------------+--------------------+-------------+------------------+
# |     entity|            instance|               name|               value| dataset_date|               tag|
# +-----------+--------------------+-------------------+--------------------+-------------+------------------+
# |     Column|              Emp ID|       Completeness|                 1.0|1617948736024|          analyzer|
# |     Column|              Emp ID|ApproxCountDistinct|               990.0|1617948736024|          analyzer|
# |     Column|    Month of Joining|       Completeness|                 1.0|1617948736024|          analyzer|
# |Mutlicolumn|Age in Yrs,Age in...|  MutualInformation|   3.129138342929379|1617948736024|          analyzer|
# |Mutlicolumn|Age in Yrs,Weight...|  MutualInformation|  3.6304269674121072|1617948736024|          analyzer|
# |Mutlicolumn|   Age in Yrs,Salary|        Correlation|0.041421648278586576|1617948736024|          analyzer|
# |    Dataset|                   *|               Size|              1000.0|1617948736024|          analyzer|
# |     Column|              Salary|               Mean|          120288.528|1617948736024|          analyzer|
# |     Column|Salary greater th...|         Compliance|               0.932|1617948736024|          analyzer|
# |Mutlicolumn|Age in Company (Y...|        Correlation|   0.675074596712711|1617948736024|          analyzer|
# |Mutlicolumn|Age in Yrs,Weight...|        Correlation| -0.0656561971574341|1617948736024|          analyzer|
# |     Column|    Month of Joining|       Completeness|                 1.0|1617949242630|verification_Check|
# |     Column|                 SSN|       PatternMatch|                 1.0|1617949242630|verification_Check|
# |     Column|Month of Joining ...|         Compliance|                 0.0|1617949242630|verification_Check|
# |    Dataset|                   *|               Size|              1000.0|1617949242630|verification_Check|
# |     Column|              E Mail|       PatternMatch|                 1.0|1617949242630|verification_Check|
# |     Column|              Emp ID|         Uniqueness|                 1.0|1617949242630|verification_Check|
# |     Column|            Phone No|       Completeness|                 0.0|1617949242630|verification_Check|
# |     Column|          First Name|       Completeness|                 1.0|1617949242630|verification_Check|
# |     Column|              Emp ID|       Completeness|                 1.0|1617960206759|          analyzer|
# +-----------+--------------------+-------------------+--------------------+-------------+------------------+
# only showing top 20 rows

# %%
####constraint suggestion
from pydeequ.suggestions import *

suggestionResult = ConstraintSuggestionRunner(spark) \
             .onData(df) \
             .addConstraintRule(DEFAULT()) \
             .run()

# Constraint Suggestions in JSON format
print(json.dumps(suggestionResult, indent=2))
# Out:
# {
#   "constraint_suggestions": [
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Month of Joining,None))",
#       "column_name": "Month of Joining",
#       "current_value": "Completeness: 1.0",
#       "description": "'Month of Joining' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Month of Joining\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Month of Joining' has no negative values,Month of Joining >= 0,None))",
#       "column_name": "Month of Joining",
#       "current_value": "Minimum: 1.0",
#       "description": "'Month of Joining' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"Month of Joining\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(First Name,None))",
#       "column_name": "First Name",
#       "current_value": "Completeness: 1.0",
#       "description": "'First Name' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"First Name\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Short Month' has value range 'Apr', 'Oct', 'May', 'Aug', 'Feb', 'Jun', 'Jan', 'Nov', 'Dec', 'Mar', 'Jul', 'Sep',`Short Month` IN ('Apr', 'Oct', 'May', 'Aug', 'Feb', 'Jun', 'Jan', 'Nov', 'Dec', 'Mar', 'Jul', 'Sep'),None))",
#       "column_name": "Short Month",
#       "current_value": "Compliance: 1",
#       "description": "'Short Month' has value range 'Apr', 'Oct', 'May', 'Aug', 'Feb', 'Jun', 'Jan', 'Nov', 'Dec', 'Mar', 'Jul', 'Sep'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"Short Month\", [\"Apr\", \"Oct\", \"May\", \"Aug\", \"Feb\", \"Jun\", \"Jan\", \"Nov\", \"Dec\", \"Mar\", \"Jul\", \"Sep\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Short Month,None))",
#       "column_name": "Short Month",
#       "current_value": "Completeness: 1.0",
#       "description": "'Short Month' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Short Month\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Short Month' has value range 'Apr', 'Oct', 'May', 'Aug', 'Feb', 'Jun', 'Jan', 'Nov', 'Dec', 'Mar', 'Jul' for at least 91.0% of values,`Short Month` IN ('Apr', 'Oct', 'May', 'Aug', 'Feb', 'Jun', 'Jan', 'Nov', 'Dec', 'Mar', 'Jul'),None))",
#       "column_name": "Short Month",
#       "current_value": "Compliance: 0.9339999999999999",
#       "description": "'Short Month' has value range 'Apr', 'Oct', 'May', 'Aug', 'Feb', 'Jun', 'Jan', 'Nov', 'Dec', 'Mar', 'Jul' for at least 91.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9)",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"Short Month\", [\"Apr\", \"Oct\", \"May\", \"Aug\", \"Feb\", \"Jun\", \"Jan\", \"Nov\", \"Dec\", \"Mar\", \"Jul\"], lambda x: x >= 0.91, \"It should be above 0.91!\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Last Name,None))",
#       "column_name": "Last Name",
#       "current_value": "Completeness: 1.0",
#       "description": "'Last Name' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Last Name\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Year of Joining,None))",
#       "column_name": "Year of Joining",
#       "current_value": "Completeness: 1.0",
#       "description": "'Year of Joining' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Year of Joining\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Year of Joining' has no negative values,Year of Joining >= 0,None))",
#       "column_name": "Year of Joining",
#       "current_value": "Minimum: 1980.0",
#       "description": "'Year of Joining' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"Year of Joining\")"
#     },
#     {
#       "constraint_name": "AnalysisBasedConstraint(DataType(Year of Joining,None),<function1>,Some(<function1>),None)",
#       "column_name": "Year of Joining",
#       "current_value": "DataType: Integral",
#       "description": "'Year of Joining' has type Integral",
#       "suggesting_rule": "RetainTypeRule()",
#       "rule_description": "If we detect a non-string type, we suggest a type constraint",
#       "code_for_constraint": ".hasDataType(\"Year of Joining\", ConstrainableDataTypes.Integral)"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(User Name,None))",
#       "column_name": "User Name",
#       "current_value": "Completeness: 1.0",
#       "description": "'User Name' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"User Name\")"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(User Name),None))",
#       "column_name": "User Name",
#       "current_value": "ApproxDistinctness: 0.975",
#       "description": "'User Name' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"User Name\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Region' has value range 'South', 'Midwest', 'Northeast', 'West',`Region` IN ('South', 'Midwest', 'Northeast', 'West'),None))",
#       "column_name": "Region",
#       "current_value": "Compliance: 1",
#       "description": "'Region' has value range 'South', 'Midwest', 'Northeast', 'West'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"Region\", [\"South\", \"Midwest\", \"Northeast\", \"West\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Region,None))",
#       "column_name": "Region",
#       "current_value": "Completeness: 1.0",
#       "description": "'Region' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Region\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Region' has value range 'South', 'Midwest', 'Northeast', 'West' for at least 99.0% of values,`Region` IN ('South', 'Midwest', 'Northeast', 'West'),None))",
#       "column_name": "Region",
#       "current_value": "Compliance: 0.9999999999999999",
#       "description": "'Region' has value range 'South', 'Midwest', 'Northeast', 'West' for at least 99.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9)",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"Region\", [\"South\", \"Midwest\", \"Northeast\", \"West\"], lambda x: x >= 0.99, \"It should be above 0.99!\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Place Name,None))",
#       "column_name": "Place Name",
#       "current_value": "Completeness: 1.0",
#       "description": "'Place Name' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Place Name\")"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(Place Name),None))",
#       "column_name": "Place Name",
#       "current_value": "ApproxDistinctness: 0.924",
#       "description": "'Place Name' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"Place Name\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('DOW of Joining' has value range 'Sunday', 'Friday', 'Saturday', 'Wednesday', 'Monday', 'Tuesday', 'Thursday',`DOW of Joining` IN ('Sunday', 'Friday', 'Saturday', 'Wednesday', 'Monday', 'Tuesday', 'Thursday'),None))",
#       "column_name": "DOW of Joining",
#       "current_value": "Compliance: 1",
#       "description": "'DOW of Joining' has value range 'Sunday', 'Friday', 'Saturday', 'Wednesday', 'Monday', 'Tuesday', 'Thursday'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"DOW of Joining\", [\"Sunday\", \"Friday\", \"Saturday\", \"Wednesday\", \"Monday\", \"Tuesday\", \"Thursday\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(DOW of Joining,None))",
#       "column_name": "DOW of Joining",
#       "current_value": "Completeness: 1.0",
#       "description": "'DOW of Joining' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"DOW of Joining\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Emp ID,None))",
#       "column_name": "Emp ID",
#       "current_value": "Completeness: 1.0",
#       "description": "'Emp ID' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Emp ID\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Emp ID' has no negative values,Emp ID >= 0,None))",
#       "column_name": "Emp ID",
#       "current_value": "Minimum: 114425.0",
#       "description": "'Emp ID' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"Emp ID\")"
#     },
#     {
#       "constraint_name": "AnalysisBasedConstraint(DataType(Emp ID,None),<function1>,Some(<function1>),None)",
#       "column_name": "Emp ID",
#       "current_value": "DataType: Integral",
#       "description": "'Emp ID' has type Integral",
#       "suggesting_rule": "RetainTypeRule()",
#       "rule_description": "If we detect a non-string type, we suggest a type constraint",
#       "code_for_constraint": ".hasDataType(\"Emp ID\", ConstrainableDataTypes.Integral)"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(Emp ID),None))",
#       "column_name": "Emp ID",
#       "current_value": "ApproxDistinctness: 0.99",
#       "description": "'Emp ID' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"Emp ID\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Age in Company (Years),None))",
#       "column_name": "Age in Company (Years)",
#       "current_value": "Completeness: 1.0",
#       "description": "'Age in Company (Years)' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Age in Company (Years)\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Age in Company (Years)' has no negative values,Age in Company (Years) >= 0,None))",
#       "column_name": "Age in Company (Years)",
#       "current_value": "Minimum: 0.0",
#       "description": "'Age in Company (Years)' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"Age in Company (Years)\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Password,None))",
#       "column_name": "Password",
#       "current_value": "Completeness: 1.0",
#       "description": "'Password' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Password\")"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(Password),None))",
#       "column_name": "Password",
#       "current_value": "ApproxDistinctness: 1.003",
#       "description": "'Password' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"Password\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Name Prefix' has value range 'Mr.', 'Ms.', 'Mrs.', 'Hon.', 'Dr.', 'Drs.', 'Prof.',`Name Prefix` IN ('Mr.', 'Ms.', 'Mrs.', 'Hon.', 'Dr.', 'Drs.', 'Prof.'),None))",
#       "column_name": "Name Prefix",
#       "current_value": "Compliance: 1",
#       "description": "'Name Prefix' has value range 'Mr.', 'Ms.', 'Mrs.', 'Hon.', 'Dr.', 'Drs.', 'Prof.'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"Name Prefix\", [\"Mr.\", \"Ms.\", \"Mrs.\", \"Hon.\", \"Dr.\", \"Drs.\", \"Prof.\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Name Prefix,None))",
#       "column_name": "Name Prefix",
#       "current_value": "Completeness: 1.0",
#       "description": "'Name Prefix' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Name Prefix\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Name Prefix' has value range 'Mr.', 'Ms.', 'Mrs.', 'Hon.', 'Dr.', 'Drs.' for at least 93.0% of values,`Name Prefix` IN ('Mr.', 'Ms.', 'Mrs.', 'Hon.', 'Dr.', 'Drs.'),None))",
#       "column_name": "Name Prefix",
#       "current_value": "Compliance: 0.9459999999999998",
#       "description": "'Name Prefix' has value range 'Mr.', 'Ms.', 'Mrs.', 'Hon.', 'Dr.', 'Drs.' for at least 93.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9)",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"Name Prefix\", [\"Mr.\", \"Ms.\", \"Mrs.\", \"Hon.\", \"Dr.\", \"Drs.\"], lambda x: x >= 0.93, \"It should be above 0.93!\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Half of Joining' has value range 'H1', 'H2',`Half of Joining` IN ('H1', 'H2'),None))",
#       "column_name": "Half of Joining",
#       "current_value": "Compliance: 1",
#       "description": "'Half of Joining' has value range 'H1', 'H2'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"Half of Joining\", [\"H1\", \"H2\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Half of Joining,None))",
#       "column_name": "Half of Joining",
#       "current_value": "Completeness: 1.0",
#       "description": "'Half of Joining' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Half of Joining\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(County,None))",
#       "column_name": "County",
#       "current_value": "Completeness: 1.0",
#       "description": "'County' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"County\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Time of Birth,None))",
#       "column_name": "Time of Birth",
#       "current_value": "Completeness: 1.0",
#       "description": "'Time of Birth' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Time of Birth\")"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(Time of Birth),None))",
#       "column_name": "Time of Birth",
#       "current_value": "ApproxDistinctness: 1.005",
#       "description": "'Time of Birth' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"Time of Birth\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(City,None))",
#       "column_name": "City",
#       "current_value": "Completeness: 1.0",
#       "description": "'City' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"City\")"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(City),None))",
#       "column_name": "City",
#       "current_value": "ApproxDistinctness: 0.924",
#       "description": "'City' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"City\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Age in Yrs,None))",
#       "column_name": "Age in Yrs",
#       "current_value": "Completeness: 1.0",
#       "description": "'Age in Yrs' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Age in Yrs\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Age in Yrs' has no negative values,Age in Yrs >= 0,None))",
#       "column_name": "Age in Yrs",
#       "current_value": "Minimum: 21.04",
#       "description": "'Age in Yrs' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"Age in Yrs\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Salary,None))",
#       "column_name": "Salary",
#       "current_value": "Completeness: 1.0",
#       "description": "'Salary' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Salary\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Salary' has no negative values,Salary >= 0,None))",
#       "column_name": "Salary",
#       "current_value": "Minimum: 40040.0",
#       "description": "'Salary' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"Salary\")"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(Salary),None))",
#       "column_name": "Salary",
#       "current_value": "ApproxDistinctness: 0.97",
#       "description": "'Salary' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"Salary\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Date of Birth,None))",
#       "column_name": "Date of Birth",
#       "current_value": "Completeness: 1.0",
#       "description": "'Date of Birth' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Date of Birth\")"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(Date of Birth),None))",
#       "column_name": "Date of Birth",
#       "current_value": "ApproxDistinctness: 0.963",
#       "description": "'Date of Birth' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"Date of Birth\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Month Name of Joining' has value range 'April', 'October', 'May', 'August', 'February', 'June', 'January', 'November', 'December', 'March', 'July', 'September',`Month Name of Joining` IN ('April', 'October', 'May', 'August', 'February', 'June', 'January', 'November', 'December', 'March', 'July', 'September'),None))",
#       "column_name": "Month Name of Joining",
#       "current_value": "Compliance: 1",
#       "description": "'Month Name of Joining' has value range 'April', 'October', 'May', 'August', 'February', 'June', 'January', 'November', 'December', 'March', 'July', 'September'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"Month Name of Joining\", [\"April\", \"October\", \"May\", \"August\", \"February\", \"June\", \"January\", \"November\", \"December\", \"March\", \"July\", \"September\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Month Name of Joining,None))",
#       "column_name": "Month Name of Joining",
#       "current_value": "Completeness: 1.0",
#       "description": "'Month Name of Joining' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Month Name of Joining\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Month Name of Joining' has value range 'April', 'October', 'May', 'August', 'February', 'June', 'January', 'November', 'December', 'March', 'July' for at least 91.0% of values,`Month Name of Joining` IN ('April', 'October', 'May', 'August', 'February', 'June', 'January', 'November', 'December', 'March', 'July'),None))",
#       "column_name": "Month Name of Joining",
#       "current_value": "Compliance: 0.9339999999999998",
#       "description": "'Month Name of Joining' has value range 'April', 'October', 'May', 'August', 'February', 'June', 'January', 'November', 'December', 'March', 'July' for at least 91.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9)",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"Month Name of Joining\", [\"April\", \"October\", \"May\", \"August\", \"February\", \"June\", \"January\", \"November\", \"December\", \"March\", \"July\"], lambda x: x >= 0.91, \"It should be above 0.91!\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Zip,None))",
#       "column_name": "Zip",
#       "current_value": "Completeness: 1.0",
#       "description": "'Zip' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Zip\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Zip' has no negative values,Zip >= 0,None))",
#       "column_name": "Zip",
#       "current_value": "Minimum: 1002.0",
#       "description": "'Zip' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"Zip\")"
#     },
#     {
#       "constraint_name": "AnalysisBasedConstraint(DataType(Zip,None),<function1>,Some(<function1>),None)",
#       "column_name": "Zip",
#       "current_value": "DataType: Integral",
#       "description": "'Zip' has type Integral",
#       "suggesting_rule": "RetainTypeRule()",
#       "rule_description": "If we detect a non-string type, we suggest a type constraint",
#       "code_for_constraint": ".hasDataType(\"Zip\", ConstrainableDataTypes.Integral)"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(Zip),None))",
#       "column_name": "Zip",
#       "current_value": "ApproxDistinctness: 0.993",
#       "description": "'Zip' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"Zip\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(E Mail,None))",
#       "column_name": "E Mail",
#       "current_value": "Completeness: 1.0",
#       "description": "'E Mail' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"E Mail\")"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(E Mail),None))",
#       "column_name": "E Mail",
#       "current_value": "ApproxDistinctness: 1.014",
#       "description": "'E Mail' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"E Mail\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Short DOW' has value range 'Sun', 'Fri', 'Sat', 'Wed', 'Mon', 'Tue', 'Thu',`Short DOW` IN ('Sun', 'Fri', 'Sat', 'Wed', 'Mon', 'Tue', 'Thu'),None))",
#       "column_name": "Short DOW",
#       "current_value": "Compliance: 1",
#       "description": "'Short DOW' has value range 'Sun', 'Fri', 'Sat', 'Wed', 'Mon', 'Tue', 'Thu'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"Short DOW\", [\"Sun\", \"Fri\", \"Sat\", \"Wed\", \"Mon\", \"Tue\", \"Thu\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Short DOW,None))",
#       "column_name": "Short DOW",
#       "current_value": "Completeness: 1.0",
#       "description": "'Short DOW' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Short DOW\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Father's Name,None))",
#       "column_name": "Father's Name",
#       "current_value": "Completeness: 1.0",
#       "description": "'Father's Name' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Father's Name\")"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(Father's Name),None))",
#       "column_name": "Father's Name",
#       "current_value": "ApproxDistinctness: 0.987",
#       "description": "'Father's Name' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"Father's Name\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('State' has value range 'PA', 'CA', 'TX', 'NY', 'FL', 'IL', 'VA', 'OH', 'KY', 'NC', 'IA', 'WI', 'MO', 'IN', 'MI', 'KS', 'MN', 'MS', 'WV', 'AL', 'GA', 'WA', 'OK', 'LA', 'AR', 'NE', 'ME', 'TN', 'CO', 'NJ', 'MA', 'SC', 'ND', 'MD', 'OR', 'AK', 'CT', 'AZ', 'NH', 'MT', 'NM', 'WY', 'DE', 'UT', 'DC', 'ID', 'SD', 'VT', 'NV', 'RI',`State` IN ('PA', 'CA', 'TX', 'NY', 'FL', 'IL', 'VA', 'OH', 'KY', 'NC', 'IA', 'WI', 'MO', 'IN', 'MI', 'KS', 'MN', 'MS', 'WV', 'AL', 'GA', 'WA', 'OK', 'LA', 'AR', 'NE', 'ME', 'TN', 'CO', 'NJ', 'MA', 'SC', 'ND', 'MD', 'OR', 'AK', 'CT', 'AZ', 'NH', 'MT', 'NM', 'WY', 'DE', 'UT', 'DC', 'ID', 'SD', 'VT', 'NV', 'RI'),None))",
#       "column_name": "State",
#       "current_value": "Compliance: 1",
#       "description": "'State' has value range 'PA', 'CA', 'TX', 'NY', 'FL', 'IL', 'VA', 'OH', 'KY', 'NC', 'IA', 'WI', 'MO', 'IN', 'MI', 'KS', 'MN', 'MS', 'WV', 'AL', 'GA', 'WA', 'OK', 'LA', 'AR', 'NE', 'ME', 'TN', 'CO', 'NJ', 'MA', 'SC', 'ND', 'MD', 'OR', 'AK', 'CT', 'AZ', 'NH', 'MT', 'NM', 'WY', 'DE', 'UT', 'DC', 'ID', 'SD', 'VT', 'NV', 'RI'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"State\", [\"PA\", \"CA\", \"TX\", \"NY\", \"FL\", \"IL\", \"VA\", \"OH\", \"KY\", \"NC\", \"IA\", \"WI\", \"MO\", \"IN\", \"MI\", \"KS\", \"MN\", \"MS\", \"WV\", \"AL\", \"GA\", \"WA\", \"OK\", \"LA\", \"AR\", \"NE\", \"ME\", \"TN\", \"CO\", \"NJ\", \"MA\", \"SC\", \"ND\", \"MD\", \"OR\", \"AK\", \"CT\", \"AZ\", \"NH\", \"MT\", \"NM\", \"WY\", \"DE\", \"UT\", \"DC\", \"ID\", \"SD\", \"VT\", \"NV\", \"RI\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(State,None))",
#       "column_name": "State",
#       "current_value": "Completeness: 1.0",
#       "description": "'State' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"State\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('State' has value range 'PA', 'CA', 'TX', 'NY', 'FL', 'IL', 'VA', 'OH', 'KY', 'NC', 'IA', 'WI', 'MO', 'IN', 'MI', 'KS', 'MN', 'MS', 'WV', 'AL', 'GA', 'WA', 'OK', 'LA', 'AR', 'NE', 'ME', 'TN', 'CO', 'NJ', 'MA', 'SC', 'ND', 'MD', 'OR' for at least 88.0% of values,`State` IN ('PA', 'CA', 'TX', 'NY', 'FL', 'IL', 'VA', 'OH', 'KY', 'NC', 'IA', 'WI', 'MO', 'IN', 'MI', 'KS', 'MN', 'MS', 'WV', 'AL', 'GA', 'WA', 'OK', 'LA', 'AR', 'NE', 'ME', 'TN', 'CO', 'NJ', 'MA', 'SC', 'ND', 'MD', 'OR'),None))",
#       "column_name": "State",
#       "current_value": "Compliance: 0.9010000000000005",
#       "description": "'State' has value range 'PA', 'CA', 'TX', 'NY', 'FL', 'IL', 'VA', 'OH', 'KY', 'NC', 'IA', 'WI', 'MO', 'IN', 'MI', 'KS', 'MN', 'MS', 'WV', 'AL', 'GA', 'WA', 'OK', 'LA', 'AR', 'NE', 'ME', 'TN', 'CO', 'NJ', 'MA', 'SC', 'ND', 'MD', 'OR' for at least 88.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9)",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"State\", [\"PA\", \"CA\", \"TX\", \"NY\", \"FL\", \"IL\", \"VA\", \"OH\", \"KY\", \"NC\", \"IA\", \"WI\", \"MO\", \"IN\", \"MI\", \"KS\", \"MN\", \"MS\", \"WV\", \"AL\", \"GA\", \"WA\", \"OK\", \"LA\", \"AR\", \"NE\", \"ME\", \"TN\", \"CO\", \"NJ\", \"MA\", \"SC\", \"ND\", \"MD\", \"OR\"], lambda x: x >= 0.88, \"It should be above 0.88!\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Mother's Maiden Name,None))",
#       "column_name": "Mother's Maiden Name",
#       "current_value": "Completeness: 1.0",
#       "description": "'Mother's Maiden Name' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Mother's Maiden Name\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Gender' has value range 'M', 'F',`Gender` IN ('M', 'F'),None))",
#       "column_name": "Gender",
#       "current_value": "Compliance: 1",
#       "description": "'Gender' has value range 'M', 'F'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"Gender\", [\"M\", \"F\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Gender,None))",
#       "column_name": "Gender",
#       "current_value": "Completeness: 1.0",
#       "description": "'Gender' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Gender\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(SSN,None))",
#       "column_name": "SSN",
#       "current_value": "Completeness: 1.0",
#       "description": "'SSN' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"SSN\")"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(SSN),None))",
#       "column_name": "SSN",
#       "current_value": "ApproxDistinctness: 0.979",
#       "description": "'SSN' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"SSN\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Middle Initial' has value range 'J', 'L', 'R', 'H', 'Z', 'A', 'C', 'S', 'D', 'V', 'G', 'M', 'Y', 'Q', 'P', 'I', 'N', 'E', 'T', 'X', 'K', 'W', 'F', 'O', 'B', 'U',`Middle Initial` IN ('J', 'L', 'R', 'H', 'Z', 'A', 'C', 'S', 'D', 'V', 'G', 'M', 'Y', 'Q', 'P', 'I', 'N', 'E', 'T', 'X', 'K', 'W', 'F', 'O', 'B', 'U'),None))",
#       "column_name": "Middle Initial",
#       "current_value": "Compliance: 1",
#       "description": "'Middle Initial' has value range 'J', 'L', 'R', 'H', 'Z', 'A', 'C', 'S', 'D', 'V', 'G', 'M', 'Y', 'Q', 'P', 'I', 'N', 'E', 'T', 'X', 'K', 'W', 'F', 'O', 'B', 'U'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"Middle Initial\", [\"J\", \"L\", \"R\", \"H\", \"Z\", \"A\", \"C\", \"S\", \"D\", \"V\", \"G\", \"M\", \"Y\", \"Q\", \"P\", \"I\", \"N\", \"E\", \"T\", \"X\", \"K\", \"W\", \"F\", \"O\", \"B\", \"U\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Middle Initial,None))",
#       "column_name": "Middle Initial",
#       "current_value": "Completeness: 1.0",
#       "description": "'Middle Initial' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Middle Initial\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Middle Initial' has value range 'J', 'L', 'R', 'H', 'Z', 'A', 'C', 'S', 'D', 'V', 'G', 'M', 'Y', 'Q', 'P', 'I', 'N', 'E', 'T', 'X', 'K', 'W', 'F' for at least 89.0% of values,`Middle Initial` IN ('J', 'L', 'R', 'H', 'Z', 'A', 'C', 'S', 'D', 'V', 'G', 'M', 'Y', 'Q', 'P', 'I', 'N', 'E', 'T', 'X', 'K', 'W', 'F'),None))",
#       "column_name": "Middle Initial",
#       "current_value": "Compliance: 0.9100000000000003",
#       "description": "'Middle Initial' has value range 'J', 'L', 'R', 'H', 'Z', 'A', 'C', 'S', 'D', 'V', 'G', 'M', 'Y', 'Q', 'P', 'I', 'N', 'E', 'T', 'X', 'K', 'W', 'F' for at least 89.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9)",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"Middle Initial\", [\"J\", \"L\", \"R\", \"H\", \"Z\", \"A\", \"C\", \"S\", \"D\", \"V\", \"G\", \"M\", \"Y\", \"Q\", \"P\", \"I\", \"N\", \"E\", \"T\", \"X\", \"K\", \"W\", \"F\"], lambda x: x >= 0.89, \"It should be above 0.89!\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Weight in Kgs,None))",
#       "column_name": "Weight in Kgs",
#       "current_value": "Completeness: 1.0",
#       "description": "'Weight in Kgs' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Weight in Kgs\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Weight in Kgs' has no negative values,Weight in Kgs >= 0,None))",
#       "column_name": "Weight in Kgs",
#       "current_value": "Minimum: 40.0",
#       "description": "'Weight in Kgs' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"Weight in Kgs\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Mother's Name,None))",
#       "column_name": "Mother's Name",
#       "current_value": "Completeness: 1.0",
#       "description": "'Mother's Name' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Mother's Name\")"
#     },
#     {
#       "constraint_name": "UniquenessConstraint(Uniqueness(List(Mother's Name),None))",
#       "column_name": "Mother's Name",
#       "current_value": "ApproxDistinctness: 1.066",
#       "description": "'Mother's Name' is unique",
#       "suggesting_rule": "UniqueIfApproximatelyUniqueRule()",
#       "rule_description": "If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint",
#       "code_for_constraint": ".isUnique(\"Mother's Name\")"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Day of Joining,None))",
#       "column_name": "Day of Joining",
#       "current_value": "Completeness: 1.0",
#       "description": "'Day of Joining' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Day of Joining\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Day of Joining' has no negative values,Day of Joining >= 0,None))",
#       "column_name": "Day of Joining",
#       "current_value": "Minimum: 1.0",
#       "description": "'Day of Joining' has no negative values",
#       "suggesting_rule": "NonNegativeNumbersRule()",
#       "rule_description": "If we see only non-negative numbers in a column, we suggest a corresponding constraint",
#       "code_for_constraint": ".isNonNegative(\"Day of Joining\")"
#     },
#     {
#       "constraint_name": "AnalysisBasedConstraint(DataType(Day of Joining,None),<function1>,Some(<function1>),None)",
#       "column_name": "Day of Joining",
#       "current_value": "DataType: Integral",
#       "description": "'Day of Joining' has type Integral",
#       "suggesting_rule": "RetainTypeRule()",
#       "rule_description": "If we detect a non-string type, we suggest a type constraint",
#       "code_for_constraint": ".hasDataType(\"Day of Joining\", ConstrainableDataTypes.Integral)"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Quarter of Joining' has value range 'Q2', 'Q4', 'Q1', 'Q3',`Quarter of Joining` IN ('Q2', 'Q4', 'Q1', 'Q3'),None))",
#       "column_name": "Quarter of Joining",
#       "current_value": "Compliance: 1",
#       "description": "'Quarter of Joining' has value range 'Q2', 'Q4', 'Q1', 'Q3'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"Quarter of Joining\", [\"Q2\", \"Q4\", \"Q1\", \"Q3\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Quarter of Joining,None))",
#       "column_name": "Quarter of Joining",
#       "current_value": "Completeness: 1.0",
#       "description": "'Quarter of Joining' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Quarter of Joining\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Last % Hike' has value range '16%', '9%', '24%', '27%', '30%', '17%', '1%', '25%', '23%', '22%', '5%', '20%', '15%', '26%', '2%', '13%', '0%', '28%', '3%', '18%', '11%', '4%', '6%', '14%', '21%', '19%', '29%', '10%', '12%', '8%', '7%',`Last % Hike` IN ('16%', '9%', '24%', '27%', '30%', '17%', '1%', '25%', '23%', '22%', '5%', '20%', '15%', '26%', '2%', '13%', '0%', '28%', '3%', '18%', '11%', '4%', '6%', '14%', '21%', '19%', '29%', '10%', '12%', '8%', '7%'),None))",
#       "column_name": "Last % Hike",
#       "current_value": "Compliance: 1",
#       "description": "'Last % Hike' has value range '16%', '9%', '24%', '27%', '30%', '17%', '1%', '25%', '23%', '22%', '5%', '20%', '15%', '26%', '2%', '13%', '0%', '28%', '3%', '18%', '11%', '4%', '6%', '14%', '21%', '19%', '29%', '10%', '12%', '8%', '7%'",
#       "suggesting_rule": "CategoricalRangeRule()",
#       "rule_description": "If we see a categorical range for a column, we suggest an IS IN (...) constraint",
#       "code_for_constraint": ".isContainedIn(\"Last % Hike\", [\"16%\", \"9%\", \"24%\", \"27%\", \"30%\", \"17%\", \"1%\", \"25%\", \"23%\", \"22%\", \"5%\", \"20%\", \"15%\", \"26%\", \"2%\", \"13%\", \"0%\", \"28%\", \"3%\", \"18%\", \"11%\", \"4%\", \"6%\", \"14%\", \"21%\", \"19%\", \"29%\", \"10%\", \"12%\", \"8%\", \"7%\"])"
#     },
#     {
#       "constraint_name": "CompletenessConstraint(Completeness(Last % Hike,None))",
#       "column_name": "Last % Hike",
#       "current_value": "Completeness: 1.0",
#       "description": "'Last % Hike' is not null",
#       "suggesting_rule": "CompleteIfCompleteRule()",
#       "rule_description": "If a column is complete in the sample, we suggest a NOT NULL constraint",
#       "code_for_constraint": ".isComplete(\"Last % Hike\")"
#     },
#     {
#       "constraint_name": "ComplianceConstraint(Compliance('Last % Hike' has value range '16%', '9%', '24%', '27%', '30%', '17%', '1%', '25%', '23%', '22%', '5%', '20%', '15%', '26%', '2%', '13%', '0%', '28%', '3%', '18%', '11%', '4%', '6%', '14%', '21%', '19%', '29%' for at least 88.0% of values,`Last % Hike` IN ('16%', '9%', '24%', '27%', '30%', '17%', '1%', '25%', '23%', '22%', '5%', '20%', '15%', '26%', '2%', '13%', '0%', '28%', '3%', '18%', '11%', '4%', '6%', '14%', '21%', '19%', '29%'),None))",
#       "column_name": "Last % Hike",
#       "current_value": "Compliance: 0.9050000000000004",
#       "description": "'Last % Hike' has value range '16%', '9%', '24%', '27%', '30%', '17%', '1%', '25%', '23%', '22%', '5%', '20%', '15%', '26%', '2%', '13%', '0%', '28%', '3%', '18%', '11%', '4%', '6%', '14%', '21%', '19%', '29%' for at least 88.0% of values",
#       "suggesting_rule": "FractionalCategoricalRangeRule(0.9)",
#       "rule_description": "If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values",
#       "code_for_constraint": ".isContainedIn(\"Last % Hike\", [\"16%\", \"9%\", \"24%\", \"27%\", \"30%\", \"17%\", \"1%\", \"25%\", \"23%\", \"22%\", \"5%\", \"20%\", \"15%\", \"26%\", \"2%\", \"13%\", \"0%\", \"28%\", \"3%\", \"18%\", \"11%\", \"4%\", \"6%\", \"14%\", \"21%\", \"19%\", \"29%\"], lambda x: x >= 0.88, \"It should be above 0.88!\")"
#     }
#   ]
# }

# %%
##show suggestion matrix as dataframe
for key, val in suggestionResult.items():
    print(key)

k =suggestionResult.get('constraint_suggestions')
#print(k)
# Out:
# constraint_suggestions

# %%
import pandas as pd

df_suggestion = pd.DataFrame.from_dict(k)
df_suggestion.head(5)
# Out:
#                                      constraint_name       column_name  \
# 0  CompletenessConstraint(Completeness(Month of J...  Month of Joining
# 1  ComplianceConstraint(Compliance('Month of Join...  Month of Joining
# 2  CompletenessConstraint(Completeness(First Name...        First Name
# 3  ComplianceConstraint(Compliance('Short Month' ...       Short Month
# 4  CompletenessConstraint(Completeness(Short Mont...       Short Month
#
#        current_value                                        description  \
# 0  Completeness: 1.0                     'Month of Joining' is not null
# 1       Minimum: 1.0          'Month of Joining' has no negative values
# 2  Completeness: 1.0                           'First Name' is not null
# 3      Compliance: 1  'Short Month' has value range 'Apr', 'Oct', 'M...
# 4  Completeness: 1.0                          'Short Month' is not null
#
#             suggesting_rule  \
# 0  CompleteIfCompleteRule()
# 1  NonNegativeNumbersRule()
# 2  CompleteIfCompleteRule()
# 3    CategoricalRangeRule()
# 4  CompleteIfCompleteRule()
#
#                                     rule_description  \
# 0  If a column is complete in the sample, we sugg...
# 1  If we see only non-negative numbers in a colum...
# 2  If a column is complete in the sample, we sugg...
# 3  If we see a categorical range for a column, we...
# 4  If a column is complete in the sample, we sugg...
#
#                                  code_for_constraint
# 0                    .isComplete("Month of Joining")
# 1                 .isNonNegative("Month of Joining")
# 2                          .isComplete("First Name")
# 3  .isContainedIn("Short Month", ["Apr", "Oct", "...
# 4                         .isComplete("Short Month")
